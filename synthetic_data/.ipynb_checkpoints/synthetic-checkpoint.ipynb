# %% [markdown]
# This notebook replicates the synthetic data experiments.

# %%
import numpy as np
import sys
sys.path.append("..")
import os
from utils import generate_synthetic_LTR_data
from fair_training_ranking import train_fair_nn
from sklearn.linear_model import LogisticRegression
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /Users/amandarg/opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# We need to delete these directories if they exist so plotting works properly

# %%
rm -r heatmaps

# %%
rm -r tensorboard_simulations

# %%
rm -r results_simulations

# %%
# create synthetic train/test data
num_docs_per_query = 10
num_queries = 100
X_queries, relevances, majority_status = generate_synthetic_LTR_data(num_queries = num_queries, num_docs_per_query = num_docs_per_query)
X_queries_test, relevances_test, majority_status_test = generate_synthetic_LTR_data(num_queries = num_queries, num_docs_per_query = num_docs_per_query)

if not os.path.exists('data'):
    os.makedirs('data')

np.save('data/X.npy', X_queries)
np.save('data/relevance.npy', relevances)
np.save('data/majority_status.npy', majority_status)
np.save('data/X_test.npy', X_queries_test)
np.save('data/relevance_test.npy', relevances_test)
np.save('data/majority_status_test.npy', majority_status_test)

# %%
#baseline
LR = LogisticRegression(C = 100).fit(X_queries, majority_status)
sens_directions = LR.coef_
print('sensitive directions', sens_directions)

_  = train_fair_nn(X_queries,
                                                        relevances,
                                                        majority_status,
                                                        X_test = X_queries_test,
                                                        relevance_test = relevances_test,
                                                        group_membership_test = majority_status_test,
                                                        num_items_per_query = num_docs_per_query,
                                                        tf_prefix='baseline',
                                                        weights=None,
                                                        n_units = [],
                                                        lr=0.04,
                                                        fair_start=1.,
                                                        batch_size=1,
                                                        epoch=20*num_queries,
                                                        verbose=True,
                                                        activ_f = tf.nn.relu,
                                                        l2_reg=0.0,
                                                        plot=True,
                                                        sens_directions=sens_directions,
                                                        seed=None,
                                                        simul=True, # need to make this true if you want to make plots
                                                        num_monte_carlo_samples = 10,
                                                        bias = False,
                                                        init_range = .0001,
                                                        entropy_regularizer = .0,
                                                        baseline_ndcg = True,
                                                        load = False
                                                        )

#Train SenSeI with different fair regularization strength
for fair_reg in [.0003, .001]:
    tf.reset_default_graph()
    print('fair_reg',fair_reg)
    _  = train_fair_nn(X_queries,
                                                        relevances,
                                                        majority_status,
                                                        num_items_per_query = num_docs_per_query,
                                                        tf_prefix='sensei',
                                                        X_test = X_queries_test,
                                                        relevance_test = relevances_test,
                                                        group_membership_test = majority_status_test,
                                                        weights=None,
                                                        n_units = [],
                                                        lr=0.04,
                                                        batch_size=1,
                                                        epoch=20*num_queries,
                                                        verbose=True,
                                                        activ_f = tf.nn.relu,
                                                        l2_reg=0.,
                                                        plot=True,
                                                        lamb_init=2.,
                                                        adv_epoch=20,
                                                        adv_step=.001,
                                                        epsilon=0.001,
                                                        sens_directions=sens_directions,
                                                        l2_attack=0.001,
                                                        adv_epoch_full=20,
                                                        fair_reg=fair_reg,
                                                        fair_start=0.,
                                                        seed=None,
                                                        simul=True,
                                                        num_monte_carlo_samples = 10,
                                                        bias = False,
                                                        init_range = .0001,
                                                        entropy_regularizer = .0,
                                                        baseline_ndcg = True,
                                                        load = True)
# Out:
# sensitive directions [[ 0.18478863 52.20840803]]
# ----iteration------ 0.0
# NDCG 0.7309957
# train loss -0.006915456
# train exposure (stochastic) 0.0
# Real and fair distances (max/min/mean):
# 3.352873534367973e-15 3.352873534367973e-15 3.352873534367973e-15
# 3.298403217222301e-15 3.298403217222301e-15 3.298403217222301e-15
#
# test NDCG (stochastic) 0.7527788
#
# train NDCG (stochastic) 0.76309574 0.0
# test group exposure (stochastic) 0.0005872294
#
# test NDCG (deterministic) 0.78188777
# test group exposure (deterministic) 0.029106844
# ----iteration------ 0.5
# NDCG 0.987805
# train loss -0.0023129887
# train exposure (stochastic) 0.0
# Real and fair distances (max/min/mean):
# 4.307665335545608e-15 4.307665335545608e-15 4.307665335545608e-15
# 3.2834845953289008e-15 3.2834845953289008e-15 3.2834845953289008e-15
#
# test NDCG (stochastic) 0.95843554
#
# train NDCG (stochastic) 0.9571515 0.0
# test group exposure (stochastic) 0.013895858
#
# test NDCG (deterministic) 0.96504366
# test group exposure (deterministic) 0.014103191
# ----iteration------ 0.9995
# NDCG 0.8795711
# train loss -0.0029158702
# train exposure (stochastic) 0.0
# Real and fair distances (max/min/mean):
# 0.5900174516146863 0.5900174516146863 0.5900174516146863
# 3.2834845953289008e-15 3.2834845953289008e-15 3.2834845953289008e-15
#
# test NDCG (stochastic) 0.95961195
#
# train NDCG (stochastic) 0.9614338 0.0
# test group exposure (stochastic) 0.0128994845
#
# test NDCG (deterministic) 0.962998
# test group exposure (deterministic) 0.013343439
# l_preds.eval(all_dict = {tf_X: proj_compl}) [[282.8525]]
# CF EUCLIDEAN distance: min 1.9458039786820225 max 6.6319450989484485 mean 4.504567456861166 median 4.503454177883519
# CF FAIR distance: min 0.19786109482644718 max 1.0737963082453579 mean 0.5515646889768208 median 0.549199301816286
#
# Final train DCG 57.655914 0.0
#
# Final train NDCG (stochastic) 0.96124506 0.0
#
# Final train group exposure (stochastic) 0.009651882 0.0
#
# Final train individual exposure (stochastic) 0.01781519146503358 0.0
#
# Final train l2_score_distance 24.51846 0.0
#
# Final train weighted KT (stochastic) 0.46637071158680704 0.0
#
# Final train scaled weighted KT (stochastic) 0.888318975543408 0.0
#
# Final train weighted reg KT (stochastic) 0.4257777777777777 0.0
#
# Final train scaled weighted reg KT (stochastic) 0.8088642836560671 0.0
#
# Final train displacement_vec KT (stochastic) [1.921 2.439 2.871 3.736 4.504 5.157 5.556 5.724 6.199 6.893] 0.0
#
# Train KL with MC 44.24196367743022
#
# Train scaled KL 9.666328790597234
#
# Train top one KL 5.0124245
#
# Train scaled top one KL 1.1626882098441251
# CF EUCLIDEAN distance: min 1.9458039786820225 max 6.6319450989484485 mean 4.504567456861166 median 4.503454177883519
# CF FAIR distance: min 0.19786109482644718 max 1.0737963082453579 mean 0.5515646889768208 median 0.549199301816286
#
# Final train NDCG (deterministic) 0.9657808 0.0
#
# Final train group exposure (deterministic) 0.009979036 0.0
#
# Final train individual exposure (deterministic) 0.019375924247747523 0.0
#
# Final train l2_score_distance 24.51846 0.0
#
# Final train weighted KT (deterministic) 0.4760225202848153 0.0
#
# Final train scaled weighted KT (derministic) 0.9038569562513175 0.0
#
# Final train weighted reg KT (deterministic) 0.42977777777777787 0.0
#
# Final train scaled weighted reg KT (deterministic) 0.8163860717841864 0.0
#
# Final train displacement_vec KT (deterministic) [1.82 2.52 2.69 3.83 4.22 5.26 5.73 5.68 6.37 6.88] 0.0
#
# Final test NDCG (stochastic) 0.95987767 0.0
# CF EUCLIDEAN distance: min 2.6861794422936 max 6.005975233822179 mean 4.465541553035263 median 4.479692498680661
# CF FAIR distance: min 0.3044833383921634 max 0.8115575708069794 mean 0.4845070962432144 median 0.47582726756794724
# PREFIX baseline
#
# Final test DCG 56.17977 0.0
#
# Final test NDCG (stochastic) 0.95987767 0.0
#
# Final group_exposure_test_stochastic 0.012951059 0.0
#
# Final test individual exposure (stochastic) 0.017529396895157284 0.0
#
# Final test l2_score_distance 24.071594 0.0
#
# Final test weighted KT (stochastic) 0.4042642520585889 0.0
#
# Final test scaled weighted KT (stochastic) 0.8689502921052482 0.0
#
# Final test reg KT (stochastic) 0.3884444444444444 0.0
#
# Final test scaled reg KT (stochastic) 0.8413703643938516 0.0
#
# Final test displacement_vec KT (stochastic) [2.368 2.715 2.978 3.48  4.221 4.6   5.568 5.718 6.435 6.917] 0.0
#
# Test KL with MC 44.662439472834336
#
# Test scaled KL 9.874094821013495
#
# Test top one KL 5.8930984
#
# Test scaled top one KL 1.3668879939851488
# CF EUCLIDEAN distance: min 2.6861794422936 max 6.005975233822179 mean 4.465541553035263 median 4.479692498680661
# CF FAIR distance: min 0.3044833383921634 max 0.8115575708069794 mean 0.4845070962432144 median 0.47582726756794724
# PREFIX baseline
#
# Final test NDCG (deterministic) 0.962998 0.0
#
# Final group_exposure_test_deterministic (deterministic) 0.013343439 0.0
#
# Final test individual exposure (deterministic) 0.019339412987728198 0.0
#
# Final test l2_score_distance 24.071594 0.0
#
# Final test weighted KT (deterministic) 0.41622950819672133 0.0
#
# Final test scaled KT (deterministic) 0.8951795701828311 0.0
#
# Final test reg KT (deterministic) 0.4000000000000001 0.0
#
# Final test scaled reg KT (deterministic) 0.8662611282427011 0.0
#
# Final test displacement_vec KT (deterministic) [2.34 2.68 2.94 3.19 4.45 4.79 5.35 6.01 6.29 6.96] 0.0
# fair_reg 0.0003
# WARNING: full attack failed: objective decreased from 0.000000 to -0.000000; skipping update steps
# Decreasing learning rate: new rate is 0.000999
# ----iteration------ 0.0
# NDCG 0.8243405
# train loss -1.955031e-06
# train exposure (stochastic) 0.014954805
# Real and fair distances (max/min/mean):
# 1.0675915249047458 1.0675915249047458 1.0675915249047458
# 5.721820760945518e-09 5.721820760945518e-09 5.721820760945518e-09
#
# test NDCG (stochastic) 0.75295055
#
# train NDCG (stochastic) 0.7645792 0.0003
# test group exposure (stochastic) 0.0009803686
#
# test NDCG (deterministic) 0.94081426
# test group exposure (deterministic) 0.010329105
# ----iteration------ 0.5
# NDCG 0.9137419
# train loss -0.015682852
# train exposure (stochastic) 0.026997045
# Real and fair distances (max/min/mean):
# 6.637274913866134 6.637274913866134 6.637274913866134
# 0.0003981985404396981 0.0003981985404396981 0.0003981985404396981
#
# test NDCG (stochastic) 0.92273486
#
# train NDCG (stochastic) 0.92768687 0.0003
# test group exposure (stochastic) 0.007730956
#
# test NDCG (deterministic) 0.9407752
# test group exposure (deterministic) 0.010611399
# FAILED attacks: subspace 0; full 1; Nans after attack 0
# before subspace 0.00468936562538147; after subspace 0.011351619847118855; before l2 0.011351619847118855; after l2 0.012123772874474525
# ----iteration------ 0.9995
# NDCG 0.8832884
# train loss -0.014886376
# train exposure (stochastic) 0.0
# Real and fair distances (max/min/mean):
# 4.286355930555435 4.286355930555435 4.286355930555435
# 0.0003981985404396981 0.0003981985404396981 0.0003981985404396981
#
# test NDCG (stochastic) 0.9246288
#
# train NDCG (stochastic) 0.9285694 0.0003
# test group exposure (stochastic) 0.00817276
#
# test NDCG (deterministic) 0.94350606
# test group exposure (deterministic) 0.010154205
# FAILED attacks: subspace 0; full 1; Nans after attack 0
# before subspace 0.0038514062762260437; after subspace 0.010490245185792446; before l2 0.010490245185792446; after l2 0.01125139556825161
# l_preds.eval(all_dict = {tf_X: proj_compl}) [[54.75754]]
# CF EUCLIDEAN distance: min 1.9458039786820225 max 6.6319450989484485 mean 4.504567456861166 median 4.503454177883519
# CF FAIR distance: min 0.19786109482644718 max 1.0737963082453579 mean 0.5515646889768208 median 0.549199301816286
#
# Final train DCG 55.72901 0.0003
#
# Final train NDCG (stochastic) 0.92853945 0.0003
#
# Final train group exposure (stochastic) 0.007523658 0.0003
#
# Final train individual exposure (stochastic) 0.015110424010830771 0.0003
#
# Final train l2_score_distance 5.115838 0.0003
#
# Final train weighted KT (stochastic) 0.6161753149979677 0.0003
#
# Final train scaled weighted KT (stochastic) 1.185572123075984 0.0003
#
# Final train weighted reg KT (stochastic) 0.5933333333333333 0.0003
#
# Final train scaled weighted reg KT (stochastic) 1.144889910042878 0.0003
#
# Final train displacement_vec KT (stochastic) [1.29  1.646 2.514 3.216 4.132 5.111 5.832 6.328 7.193 7.738] 0.0003
#
# Train KL with MC 4.583598032659
#
# Train scaled KL 1.0102293395549788
#
# Train top one KL 0.48885116
#
# Train scaled top one KL 0.11339451201672128
# CF EUCLIDEAN distance: min 1.9458039786820225 max 6.6319450989484485 mean 4.504567456861166 median 4.503454177883519
# CF FAIR distance: min 0.19786109482644718 max 1.0737963082453579 mean 0.5515646889768208 median 0.549199301816286
#
# Final train NDCG (deterministic) 0.9416531 0.0003
#
# Final train group exposure (deterministic) 0.008184466 0.0003
#
# Final train individual exposure (deterministic) 0.019763499070768888 0.0003
#
# Final train l2_score_distance 5.115838 0.0003
#
# Final train weighted KT (deterministic) 0.7564366466452905 0.0003
#
# Final train scaled weighted KT (derministic) 1.4648948691239931 0.0003
#
# Final train weighted reg KT (deterministic) 0.7324444444444445 0.0003
#
# Final train scaled weighted reg KT (deterministic) 1.417945728732249 0.0003
#
# Final train displacement_vec KT (deterministic) [0.82 1.27 2.23 3.24 3.84 5.01 6.05 6.76 7.72 8.06] 0.0003
#
# Final test NDCG (stochastic) 0.9256029 0.0003
# CF EUCLIDEAN distance: min 2.6861794422936 max 6.005975233822179 mean 4.465541553035263 median 4.479692498680661
# CF FAIR distance: min 0.3044833383921634 max 0.8115575708069794 mean 0.4845070962432144 median 0.47582726756794724
# PREFIX sensei
#
# Final test DCG 54.29346 0.0003
#
# Final test NDCG (stochastic) 0.9256029 0.0003
#
# Final group_exposure_test_stochastic 0.008023911 0.0003
#
# Final test individual exposure (stochastic) 0.015083156604279868 0.0003
#
# Final test l2_score_distance 4.8806024 0.0003
#
# Final test weighted KT (stochastic) 0.6228722395339386 0.0003
#
# Final test scaled weighted KT (stochastic) 1.3352627764410077 0.0003
#
# Final test reg KT (stochastic) 0.6013333333333333 0.0003
#
# Final test scaled reg KT (stochastic) 1.2972402309478974 0.0003
#
# Final test displacement_vec KT (stochastic) [1.327 1.853 2.368 3.332 4.189 4.806 5.577 6.47  7.253 7.825] 0.0003
#
# Test KL with MC 4.4203161926553625
#
# Test scaled KL 0.9782905789334783
#
# Test top one KL 0.59961617
#
# Test scaled top one KL 0.13907934382949505
# CF EUCLIDEAN distance: min 2.6861794422936 max 6.005975233822179 mean 4.465541553035263 median 4.479692498680661
# CF FAIR distance: min 0.3044833383921634 max 0.8115575708069794 mean 0.4845070962432144 median 0.47582726756794724
# PREFIX sensei
#
# Final test NDCG (deterministic) 0.94350606 0.0003
#
# Final group_exposure_test_deterministic (deterministic) 0.010154205 0.0003
#
# Final test individual exposure (deterministic) 0.0193064891469199 0.0003
#
# Final test l2_score_distance 4.8806024 0.0003
#
# Final test weighted KT (deterministic) 0.7282104201478269 0.0003
#
# Final test scaled KT (deterministic) 1.568180741734015 0.0003
#
# Final test reg KT (deterministic) 0.7057777777777777 0.0003
#
# Final test scaled reg KT (deterministic) 1.521058547514446 0.0003
#
# Final test displacement_vec KT (deterministic) [0.99 1.38 2.1  3.26 3.92 4.9  5.95 6.58 7.82 8.1 ] 0.0003
# Final lambda 0.000010
# fair_reg 0.001
# WARNING: full attack failed: objective decreased from 0.000000 to -0.000000; skipping update steps
# Decreasing learning rate: new rate is 0.000999
# ----iteration------ 0.0
# NDCG 0.7681991
# train loss -7.295584e-06
# train exposure (stochastic) 0.0
# Real and fair distances (max/min/mean):
# 2.587726004590598 2.587726004590598 2.587726004590598
# 2.2390211504706066e-09 2.2390211504706066e-09 2.2390211504706066e-09
#
# test NDCG (stochastic) 0.75524426
#
# train NDCG (stochastic) 0.75876975 0.001
# test group exposure (stochastic) 0.0011949567
#
# test NDCG (deterministic) 0.7645798
# test group exposure (deterministic) 0.030698093
# WARNING: full attack failed: objective decreased from 0.000000 to -0.000000; skipping update steps
# Decreasing learning rate: new rate is 0.000998
# WARNING: full attack failed: objective decreased from 0.000000 to -0.000000; skipping update steps
# Decreasing learning rate: new rate is 0.000997
# ----iteration------ 0.5
# NDCG 0.98845017
# train loss -0.0055391635
# train exposure (stochastic) 0.023335174
# Real and fair distances (max/min/mean):
# 2.0615356998368215 2.0615356998368215 2.0615356998368215
# 0.0004032362555540514 0.0004032362555540514 0.0004032362555540514
#
# test NDCG (stochastic) 0.90158236
#
# train NDCG (stochastic) 0.913901 0.001
# test group exposure (stochastic) 0.010501053
#
# test NDCG (deterministic) 0.9141104
# test group exposure (deterministic) 0.012363174
# FAILED attacks: subspace 0; full 3; Nans after attack 0
# before subspace 0.0006750237080268562; after subspace 0.0022553429007530212; before l2 0.0022553429007530212; after l2 0.003054780187085271
# ----iteration------ 0.9995
# NDCG 0.90657055
# train loss -0.013616633
# train exposure (stochastic) 0.0
# Real and fair distances (max/min/mean):
# 5.045605275546531 5.045605275546531 5.045605275546531
# 0.0004032362555540514 0.0004032362555540514 0.0004032362555540514
#
# test NDCG (stochastic) 0.9051937
#
# train NDCG (stochastic) 0.9138843 0.001
# test group exposure (stochastic) 0.0101639535
#
# test NDCG (deterministic) 0.9080942
# test group exposure (deterministic) 0.012062471
# FAILED attacks: subspace 0; full 3; Nans after attack 0
# before subspace 0.0009370426996611059; after subspace 0.002381390193477273; before l2 0.002381390193477273; after l2 0.003519840072840452
# l_preds.eval(all_dict = {tf_X: proj_compl}) [[13.75824]]
# CF EUCLIDEAN distance: min 1.9458039786820225 max 6.6319450989484485 mean 4.504567456861166 median 4.503454177883519
# CF FAIR distance: min 0.19786109482644718 max 1.0737963082453579 mean 0.5515646889768208 median 0.549199301816286
#
# Final train DCG 54.91831 0.001
#
# Final train NDCG (stochastic) 0.9152278 0.001
#
# Final train group exposure (stochastic) 0.00824656 0.001
#
# Final train individual exposure (stochastic) 0.017557549937894268 0.001
#
# Final train l2_score_distance 4.2699547 0.001
#
# Final train weighted KT (stochastic) 0.8364598292914239 0.001
#
# Final train scaled weighted KT (stochastic) 1.634656543569223 0.001
#
# Final train weighted reg KT (stochastic) 0.8257777777777778 0.001
#
# Final train scaled weighted reg KT (stochastic) 1.6115680724911918 0.001
#
# Final train displacement_vec KT (stochastic) [0.521 1.114 2.086 3.065 4.045 4.988 5.962 6.914 7.7   8.605] 0.001
#
# Train KL with MC 1.6330841564102505
#
# Train scaled KL 0.38029517760451675
#
# Train top one KL 0.16122192
#
# Train scaled top one KL 0.037397233071154924
# CF EUCLIDEAN distance: min 1.9458039786820225 max 6.6319450989484485 mean 4.504567456861166 median 4.503454177883519
# CF FAIR distance: min 0.19786109482644718 max 1.0737963082453579 mean 0.5515646889768208 median 0.549199301816286
#
# Final train NDCG (deterministic) 0.92063195 0.001
#
# Final train group exposure (deterministic) 0.008882929 0.001
#
# Final train individual exposure (deterministic) 0.019674482610737603 0.001
#
# Final train l2_score_distance 4.2699547 0.001
#
# Final train weighted KT (deterministic) 0.9675530265396136 0.001
#
# Final train scaled weighted KT (derministic) 1.8816537627255596 0.001
#
# Final train weighted reg KT (deterministic) 0.9599999999999999 0.001
#
# Final train scaled weighted reg KT (deterministic) 1.8666289350628438 0.001
#
# Final train displacement_vec KT (deterministic) [0.08 0.98 2.02 3.06 3.97 4.99 6.06 6.98 7.94 8.92] 0.001
#
# Final test NDCG (stochastic) 0.9003036 0.001
# CF EUCLIDEAN distance: min 2.6861794422936 max 6.005975233822179 mean 4.465541553035263 median 4.479692498680661
# CF FAIR distance: min 0.3044833383921634 max 0.8115575708069794 mean 0.4845070962432144 median 0.47582726756794724
# PREFIX sensei
#
# Final test DCG 52.80018 0.001
#
# Final test NDCG (stochastic) 0.9003036 0.001
#
# Final group_exposure_test_stochastic 0.011384152 0.001
#
# Final test individual exposure (stochastic) 0.017695194503371564 0.001
#
# Final test l2_score_distance 3.7018697 0.001
#
# Final test weighted KT (stochastic) 0.839781872375017 0.001
#
# Final test scaled weighted KT (stochastic) 1.7984978883839904 0.001
#
# Final test reg KT (stochastic) 0.832 0.001
#
# Final test scaled reg KT (stochastic) 1.7865976153756515 0.001
#
# Final test displacement_vec KT (stochastic) [0.544 1.112 2.117 3.078 4.081 4.886 5.947 6.923 7.744 8.568] 0.001
#
# Test KL with MC 1.2236429816206604
#
# Test scaled KL 0.2868405877312471
#
# Test top one KL 0.17222355
#
# Test scaled top one KL 0.03994678354398894
# CF EUCLIDEAN distance: min 2.6861794422936 max 6.005975233822179 mean 4.465541553035263 median 4.479692498680661
# CF FAIR distance: min 0.3044833383921634 max 0.8115575708069794 mean 0.4845070962432144 median 0.47582726756794724
# PREFIX sensei
#
# Final test NDCG (deterministic) 0.9080942 0.001
#
# Final group_exposure_test_deterministic (deterministic) 0.012062471 0.001
# Final test individual exposure (deterministic) 0.019519039558072004 0.001
#
# Final test l2_score_distance 3.7018697 0.001
#
# Final test weighted KT (deterministic) 0.9533176775203599 0.001
#
# Final test scaled KT (deterministic) 2.0450968494077504 0.001
#
# Final test reg KT (deterministic) 0.951111111111111 0.001
#
# Final test scaled reg KT (deterministic) 2.0420473560293937 0.001
#
# Final test displacement_vec KT (deterministic) [0.17 0.93 2.   3.09 3.95 4.98 6.05 6.98 7.91 8.94] 0.001
# Final lambda 0.000010

# %%
# run fair-pg-rank
# !python PG.py
# Out:
# WARNING:tensorflow:From /Users/amandarg/opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:25
# Training....
# False
# Evaluating on validation set: iteration 0/100 of epoch 0
# /Users/amandarg/opt/miniconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/amandarg/opt/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch 0, Average Validation: NDCG: 0.745176596183237, DCG 44.51421150389745, Average Rank 4.5, ERR 0.7541439743405759
# Average Validation Group Exposure disparity: 0.0034911813252012413, Group Asymmetric disparity: 0.0012947184252897984
# Training....
# LR is set to 0.05
# False
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.8587109402937501, DCG 51.59932019879748, Average Rank 4.5, ERR 0.974607531597823
# Average Validation Group Exposure disparity: 0.0032553856835027773, Group Asymmetric disparity: 0.000901337361957517
# Training....
# LR is set to 0.025
# False
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.881569565682448, DCG 53.103313135489934, Average Rank 4.5, ERR 1.0260463245852043
# Average Validation Group Exposure disparity: 0.0012673453980117514, Group Asymmetric disparity: 0.006011322165770487
# Training....
# LR is set to 0.0125
# False
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.8777099114167091, DCG 52.86758963504823, Average Rank 4.5, ERR 0.9990666415182556
# Average Validation Group Exposure disparity: 0.0013125157612431796, Group Asymmetric disparity: 0.004185467688397418
# Training....
# LR is set to 0.00625
# False
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.8823175973460171, DCG 53.06873410881267, Average Rank 4.5, ERR 1.0251360222150951
# Average Validation Group Exposure disparity: 0.0012348772066137729, Group Asymmetric disparity: 0.0030894466210087466
# Epoch 4, Average Validation: NDCG: 0.8777687659210122, DCG 52.73340794858611, Average Rank 4.5, ERR 1.010914912373923
# Average Validation Group Exposure disparity: 0.0014261008436262663, Group Asymmetric disparity: 0.0046430363125949895
# stochastic test {'ndcg': 0.8805648275617515, 'dcg': 51.63273287882758, 'avg_rank': 4.5, 'err': 1.0432554309516824, 'avg_residuals': 0.12496413982737564, 'avg_rsq': 0.5529424402399045, 'avg_l1_dists': 0.8439910077444222, 'scale_inv_mse': 0.3308705574702007, 'asymmetric_disparity': 0.005400122343986287, 'avg_group_disparity': 0.006020621886765769, 'avg_group_asym_disparity': 0.0028303294437681827}
# deterministic test {'ndcg': 0.9612915674740787, 'dcg': 56.216673199401846, 'avg_rank': 4.5, 'err': 1.2095958059384093, 'avg_residuals': 0.2233684070718305, 'avg_rsq': 0.5289331814541827, 'avg_l1_dists': 1.0181346767202104, 'scale_inv_mse': 0.344865946464591, 'asymmetric_disparity': 0.01608079479365604, 'avg_group_disparity': 0.00485967927071552, 'avg_group_asym_disparity': 0.009166282025026638}
# Learnt model for lambda=25 has model weights as [0.9066306948661804, 0.912672758102417]
# 2020-09-30 16:30:58.386507: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-09-30 16:30:58.404278: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fc76d47d6a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-09-30 16:30:58.404352: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# l_preds.eval(all_dict = {tf_X: proj_compl}) [[47.816727]]
# CF EUCLIDEAN distance: min 1.9458039786820225 max 6.6319450989484485 mean 4.504567456861166 median 4.503454177883519
# CF FAIR distance: min 0.19786109482644718 max 1.0737963082453579 mean 0.5515646889768208 median 0.549199301816286
#
# Final train DCG 53.002377 0.0
#
# Final train NDCG (stochastic) 0.88221544 0.0
#
# Final train group exposure (stochastic) 0.007761432 0.0
#
# Final train individual exposure (stochastic) 0.006584947737761413 0.0
#
# Final train l2_score_distance 4.1107845 0.0
#
# Final train weighted KT (stochastic) 0.1277404446853031 0.0
#
# Final train scaled weighted KT (stochastic) 0.22946318472700458 0.0
#
# Final train weighted reg KT (stochastic) 0.10088888888888888 0.0
#
# Final train scaled weighted reg KT (stochastic) 0.18144097456335234 0.0
#
# Final train displacement_vec KT (stochastic) [3.718 3.87  4.056 4.269 4.479 4.55  4.656 4.937 5.047 5.418] 0.0
#
# Train KL with MC 4.364152211885203
#
# Train scaled KL 0.9396321195388498
#
# Train top one KL 0.62265104
#
# Train scaled top one KL 0.1444308955136192
# CF EUCLIDEAN distance: min 1.9458039786820225 max 6.6319450989484485 mean 4.504567456861166 median 4.503454177883519
# CF FAIR distance: min 0.19786109482644718 max 1.0737963082453579 mean 0.5515646889768208 median 0.549199301816286
#
# Final train NDCG (deterministic) 0.9594724 0.0
#
# Final train group exposure (deterministic) 0.011197597 0.0
#
# Final train individual exposure (deterministic) 0.01985049016893543 0.0
#
# Final train l2_score_distance 4.1107845 0.0
#
# Final train weighted KT (deterministic) 0.2988238570503846 0.0
#
# Final train scaled weighted KT (derministic) 0.5555746512268422 0.0
#
# Final train weighted reg KT (deterministic) 0.26844444444444443 0.0
#
# Final train scaled weighted reg KT (deterministic) 0.5055098693085285 0.0
#
# Final train displacement_vec KT (deterministic) [2.87 3.21 3.48 3.55 4.93 4.67 5.35 5.45 5.27 6.22] 0.0
#
# Final test NDCG (stochastic) 0.87509507 0.0
# CF EUCLIDEAN distance: min 2.6861794422936 max 6.005975233822179 mean 4.465541553035263 median 4.479692498680661
# CF FAIR distance: min 0.3044833383921634 max 0.8115575708069794 mean 0.4845070962432144 median 0.47582726756794724
# PREFIX sensei
#
# Final test DCG 51.27297 0.0
#
# Final test NDCG (stochastic) 0.87509507 0.0
#
# Final group_exposure_test_stochastic 0.009310659 0.0
#
# Final test individual exposure (stochastic) 0.00656242136778856 0.0
#
# Final test l2_score_distance 4.0558023 0.0
#
# Final test weighted KT (stochastic) 0.06947447650875373 0.0
#
# Final test scaled weighted KT (stochastic) 0.14930101446675434 0.0
#
# Final test reg KT (stochastic) 0.07466666666666667 0.0
#
# Final test scaled reg KT (stochastic) 0.16081746316521073 0.0
#
# Final test displacement_vec KT (stochastic) [3.958 3.935 4.046 4.312 4.333 4.473 4.602 4.745 5.133 5.463] 0.0
#
# Test KL with MC 4.612752300324602
#
# Test scaled KL 1.006701462682263
#
# Test top one KL 0.6727218
#
# Test scaled top one KL 0.1560359990193411
# CF EUCLIDEAN distance: min 2.6861794422936 max 6.005975233822179 mean 4.465541553035263 median 4.479692498680661
# CF FAIR distance: min 0.3044833383921634 max 0.8115575708069794 mean 0.4845070962432144 median 0.47582726756794724
# PREFIX sensei
#
# Final test NDCG (deterministic) 0.9612917 0.0
#
# Final group_exposure_test_deterministic (deterministic) 0.016166694 0.0
#
# Final test individual exposure (deterministic) 0.019568957973407682 0.0
#
# Final test l2_score_distance 4.0558023 0.0
#
# Final test weighted KT (deterministic) 0.24176052627617456 0.0
#
# Final test scaled KT (deterministic) 0.5082911205570286 0.0
#
# Final test reg KT (deterministic) 0.22488888888888883 0.0
#
# Final test scaled reg KT (deterministic) 0.4776409327898648 0.0
#
# Final test displacement_vec KT (deterministic) [3.13 3.51 3.72 3.92 4.59 4.4  5.11 4.91 5.49 6.22] 0.0
# Traceback (most recent call last):
#   File "PG.py", line 142, in <module>
#     baseline_ndcg = True
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
# plot results
X = np.load('data/X.npy')
relevances = np.load('data/relevance.npy')
xx = np.load('data/xx.npy')
yy = np.load('data/yy.npy')
Z = np.load('data/Z_0.0.npy')
Z = Z.reshape(xx.shape)
Z_2 = np.load('data/Z_0.0003.npy')
Z_2 = Z_2.reshape(xx.shape)
Z_3 = np.load('data/Z_0.001.npy')
Z_3 = Z_3.reshape(xx.shape)

# find the minority with the highest relevance but smallest x-value
min_x_idx = 0
min_x_value = 100
max_relevance = 0
max_relevance_idx = 0
for i in range(X.shape[0]):
    if X[i,1] == 0 and X[i,0] < 1.6:
        if max_relevance < relevances[i]:
            max_relevance_idx = i
            max_relevance = relevances[i]
print(max_relevance)
#find majority

max_relevance = 0
max_relevance_idx_majority = 0
for i in range(X.shape[0]):
    if X[i,1] > 2.9 and X[i,0] < 1.7 and X[i,0]>1.2:
        if np.abs(relevances[i] - max_relevance) < 5:
            max_relevance_idx_majority = i
            break
print(relevances[i])
fig = plt.figure(figsize=(15, 5))

grid = ImageGrid(fig, 111,          # as in plt.subplot(111)
                 nrows_ncols=(1,3),
                 axes_pad=0.15,
                 share_all=True,
                 cbar_location="right",
                 cbar_mode="single",
                 cbar_size="7%",
                 cbar_pad=0.15,
                 )

cm = 'PiYG_r'

plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20)

contour = grid[0].contourf(xx, yy, Z, cmap='bwr', alpha=.8)
grid[0].set_title('Baseline: $\\rho=0$', fontsize = 25)

contour2 = grid[0].scatter(X[:,0], X[:,1], cmap=cm, c=relevances)
grid[0].scatter(X[max_relevance_idx, 0], 0, marker = '*', s=250, color = 'blue')
grid[0].scatter(X[max_relevance_idx_majority, 0], X[max_relevance_idx_majority, 1], marker = '*', s=300, color = 'black')
#plt.colorbar(contour2)
#############################
contour = grid[1].contourf(xx, yy, Z_2, cmap='bwr', alpha=.8)
grid[1].set_title('SenSTIR: $\\rho=.0003$', fontsize = 25)

contour2= grid[1].scatter(X[:,0], X[:,1], cmap=cm, c=relevances)
grid[1].scatter(X[max_relevance_idx, 0], 0, marker = '*', s=250, color = 'blue')
grid[1].scatter(X[max_relevance_idx_majority, 0], X[max_relevance_idx_majority, 1], marker = '*', s=300, color = 'black')

#plt.colorbar(contour2)
#Final group_exposure_test_stochastic 0.0103

#############################
contour = grid[2].contourf(xx, yy, Z_3, cmap='bwr', alpha=.8)
grid[2].set_title('SenSTIR: $\\rho=.001$', fontsize = 25)

contour2 = grid[2].scatter(X[:,0], X[:,1], cmap=cm, c=relevances)
grid[2].scatter(X[max_relevance_idx, 0], 0, marker = '*', s=250, color = 'blue')
grid[2].scatter(X[max_relevance_idx_majority, 0], X[max_relevance_idx_majority, 1], marker = '*', s=300, color = 'black')


grid[2].cax.colorbar(contour2)
grid[2].cax.toggle_label(True)
#Final group_exposure_test_stochastic 0.008

# plt.tight_layout()
plt.savefig('synthetic.pdf')

fig = plt.figure(figsize=(15, 4))

grid = ImageGrid(fig, 111,          # as in plt.subplot(111)
                 nrows_ncols=(1,4),
                 axes_pad=0.15,
                 share_all=True,
                 cbar_location="right",
                 cbar_mode="single",
                 cbar_size="7%",
                 cbar_pad=0.15,
                 )

plt.rc('xtick', labelsize=15) 
plt.rc('ytick', labelsize=15)

baseline_heatmap = np.load('heatmaps/baseline_adv-epoch:100_batch_size:1_adv-step:1.0_l2_attack:0.01_adv_epoch_full:10_epsilon:None_lr:0.04_MC:10_reg:0.0_epoch:2000_l2reg:0.0_init_range:0.0001_arch:_heatmap_test_stochastic_0.npy')
sensei_heatmap_1 = np.load('heatmaps/sensei_adv-epoch:20_batch_size:1_adv-step:0.001_l2_attack:0.001_adv_epoch_full:20_epsilon:0.001_lr:0.04_MC:10_reg:0.0003_epoch:2000_l2reg:0.0_init_range:0.0001_arch:_heatmap_test_stochastic_0.npy')
sensei_heatmap_2 = np.load('heatmaps/sensei_adv-epoch:20_batch_size:1_adv-step:0.001_l2_attack:0.001_adv_epoch_full:20_epsilon:0.001_lr:0.04_MC:10_reg:0.001_epoch:2000_l2reg:0.0_init_range:0.0001_arch:_heatmap_test_stochastic_0.npy')
PG_heatmap = np.load('heatmaps/sensei_adv-epoch:100_batch_size:1_adv-step:1.0_l2_attack:0.01_adv_epoch_full:10_epsilon:None_lr:0.04_MC:10_reg:0.0_epoch:0_l2reg:0.0_init_range:0.0001_arch:_heatmap_test_stochastic_0.npy')

min = np.min(np.concatenate((baseline_heatmap, sensei_heatmap_1, sensei_heatmap_2, PG_heatmap)))
max = np.max(np.concatenate((baseline_heatmap, sensei_heatmap_1, sensei_heatmap_2, PG_heatmap)))

grid[0].set_title('Baseline: $\\rho=0$', fontsize = 17)
grid[0].set_xticks(np.arange(10))
grid[0].set_xticklabels(np.arange(11)[1:])
grid[0].set_yticks(np.arange(10))
grid[0].set_yticklabels(np.arange(11)[1:])

grid[0].imshow(baseline_heatmap,vmin=min, vmax=max, aspect='auto')

#plt.colorbar(contour2)
#############################

grid[2].set_title('SenSTIR: $\\rho=.0003$', fontsize = 17)
grid[2].set_xticks(np.arange(10))
grid[2].set_xticklabels(np.arange(11)[1:])
grid[2].set_yticks(np.arange(10))
grid[2].set_yticklabels(np.arange(11)[1:])

grid[2].imshow(sensei_heatmap_1,vmin=min, vmax=max, aspect='auto')
#cbar = plt.colorbar()
#cbar.ax.tick_params(labelsize=14) 
#plt.colorbar(contour2)

#############################

grid[3].set_title('SenSTIR: $\\rho=.001$', fontsize = 17)
grid[3].set_xticks(np.arange(10))
grid[3].set_xticklabels(np.arange(11)[1:])
grid[3].set_yticks(np.arange(10))
grid[3].set_yticklabels(np.arange(11)[1:])

im = grid[3].imshow(sensei_heatmap_2,vmin=min, vmax=max, aspect='auto')
# #############################

grid[1].set_title('Fair-PG-Rank: $\\lambda=25$', fontsize = 17)
grid[1].set_xticks(np.arange(10))
grid[1].set_xticklabels(np.arange(11)[1:])
grid[1].set_yticks(np.arange(10))
grid[1].set_yticklabels(np.arange(11)[1:])
grid[1].imshow(PG_heatmap,vmin=min, vmax=max, aspect='auto')
# #############################
# plt.subplot(1, 5, 5)
# plt.title('Project', fontsize = 20)
# plt.xticks(fontsize=16)
# plt.yticks(fontsize=16)
# plt.imshow(project_heatmap, vmin=min, vmax=max, aspect='auto')
# cbar = plt.colorbar()
# cbar.ax.tick_params(labelsize=14) 

grid[3].cax.colorbar(im)
grid[3].cax.toggle_label(True)

# plt.tight_layout()

plt.savefig('heatmap.pdf')
# Out:
# 4.419375315842048
# 4.356120075048111
# /Users/amandarg/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:82: MatplotlibDeprecationWarning: Since 3.2, mpl_toolkits's own colorbar implementation is deprecated; it will be removed two minor releases later.  Set the 'mpl_toolkits.legacy_colorbar' rcParam to False to use Matplotlib's default colorbar implementation and suppress this deprecation warning.
# /Users/amandarg/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:160: MatplotlibDeprecationWarning: Since 3.2, mpl_toolkits's own colorbar implementation is deprecated; it will be removed two minor releases later.  Set the 'mpl_toolkits.legacy_colorbar' rcParam to False to use Matplotlib's default colorbar implementation and suppress this deprecation warning.
